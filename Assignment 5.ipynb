# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156]

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'originated', 'a', 'as', 'term', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['a', 'anarchism', 'originated', 'term', 'of', 'originated', 'as', 'term']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

loss_skip_gram = []
with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      loss_skip_gram.append(average_loss)
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.973211
# Nearest to s: technology, titration, uncovering, sprite, albury, consumes, wither, delayed,
# Nearest to eight: sinus, fsf, precondition, knud, schilling, birthdate, diodes, jessie,
# Nearest to is: global, versus, combats, havoc, ammunition, erudition, expressway, hermaphrodite,
# Nearest to some: northward, successor, tsr, galt, regionally, messiah, fatalism, lethal,
# Nearest to up: distinctive, grammatik, ratification, mckee, szczecin, fossils, notified, albums,
# Nearest to b: uterine, gorillas, valle, litmus, mph, breda, suppresses, forestall,
# Nearest to during: bulgarians, unsigned, radially, brother, chippewa, lunatic, fastened, legalize,
# Nearest to war: aranese, clearer, counterfeit, ambulatory, shrouded, bizkit, davenport, strive,
# Nearest to by: riaa, carrel, aleinu, siwa, serbs, weill, sacha, ignaz,
# Nearest to so: walnut, lambeth, francesco, aquilonia, cytokines, microtubule, dumfries, morr,
# Nearest to for: drummers, flambards, skin, emigrant, existent, walloon, agrarianism, depressants,
# Nearest to often: schmitt, joan, culprit, infrequently, ue, plasmas, experienced, boastful,
# Nearest to history: subway, pardons, stm, genitals, peach, dmt, aura, taxation,
# Nearest to zero: cans, curb, starving, marche, fuss, scholes, laissez, dumfries,
# Nearest to may: canon, schengen, nu, earnestly, difficulty, contarini, roo, cessna,
# Nearest to new: reluctance, phenylalanine, harpercollins, qualifications, colloquial, metaphysical, reinstating, provider,
# Average loss at step 2000: 4.378504
# Average loss at step 4000: 3.869650
# Average loss at step 6000: 3.788796
# Average loss at step 8000: 3.688551
# Average loss at step 10000: 3.613416
# Nearest to s: his, pcc, modernity, titration, technology, multicultural, lederman, sacagawea,
# Nearest to eight: nine, six, seven, five, four, three, zero, two,
# Nearest to is: was, are, has, havoc, be, if, theatrically, became,
# Nearest to some: many, successor, its, warhead, outfits, several, ursula, mentat,
# Nearest to up: distinctive, jun, ecsc, kitten, omnipotence, revue, szczecin, ratification,
# Nearest to b: d, uterine, and, reconsider, valle, breda, historiae, deansgate,
# Nearest to during: brother, necks, bulgarians, at, unsigned, syntactical, lunatic, zuma,
# Nearest to war: aranese, shrouded, ambulatory, louvain, abstention, tuareg, acquires, eider,
# Nearest to by: curran, with, hashemite, was, be, at, from, on,
# Nearest to so: pakistani, dumfries, morr, ginsberg, hel, walnut, francesco, brushed,
# Nearest to for: fraction, of, torgau, skin, with, from, neolithic, in,
# Nearest to often: there, toward, adapt, joan, also, adaptation, archivers, audrey,
# Nearest to history: taxation, stm, judges, genitals, bingen, fandango, aura, travelogues,
# Nearest to zero: nine, seven, eight, six, five, four, three, two,
# Nearest to may: can, could, grating, earnestly, virginity, scumm, canon, would,
# Nearest to new: qualifications, reinstating, until, menlo, exalted, reluctance, laughter, phenylalanine,
# Average loss at step 12000: 3.609716
# Average loss at step 14000: 3.566954
# Average loss at step 16000: 3.409246
# Average loss at step 18000: 3.460425
# Average loss at step 20000: 3.544318
# Nearest to s: lederman, competences, major, pcc, multicultural, bathing, rockville, technology,
# Nearest to eight: nine, six, seven, four, five, three, zero, two,
# Nearest to is: was, are, has, be, were, at, hammond, nnn,
# Nearest to some: many, these, several, its, their, most, successor, rein,
# Nearest to up: ecsc, jun, them, distinctive, kitten, handshake, amman, fossils,
# Nearest to b: d, valle, reconsider, perk, elicit, ethereal, counterfeiting, deansgate,
# Nearest to during: after, necks, at, through, for, unsigned, when, rap,
# Nearest to war: shrouded, aranese, abstention, wasting, eider, ambulatory, gch, louvain,
# Nearest to by: curran, were, be, into, through, hashemite, was, with,
# Nearest to so: dumfries, ginsberg, pakistani, polk, aquilonia, hel, leninist, chalice,
# Nearest to for: practitioner, of, from, with, during, torgau, rugrats, by,
# Nearest to often: also, frequently, there, who, audrey, adaptation, experienced, adapt,
# Nearest to history: taxation, travelogues, genitals, superstars, ganges, fairchild, state, bingen,
# Nearest to zero: five, six, four, seven, eight, nine, three, two,
# Nearest to may: can, would, could, will, must, grating, pyongyang, might,
# Nearest to new: qualifications, reinstating, antonov, ramzi, oysters, churchyard, base, exalted,
# Average loss at step 22000: 3.507866
# Average loss at step 24000: 3.489333
# Average loss at step 26000: 3.478515
# Average loss at step 28000: 3.481879
# Average loss at step 30000: 3.502528
# Nearest to s: lederman, his, pcc, astronomers, whose, princes, catamarans, arcologies,
# Nearest to eight: nine, five, seven, six, four, three, zero, two,
# Nearest to is: was, has, are, were, be, seems, had, cryptology,
# Nearest to some: many, these, several, their, all, most, other, ts,
# Nearest to up: them, jun, ecsc, him, kitten, out, handshake, corrective,
# Nearest to b: d, valle, elicit, perk, rory, mithraism, aggressive, plagiarized,
# Nearest to during: after, when, in, at, necks, through, corfu, before,
# Nearest to war: shrouded, aranese, eider, wasting, gch, composting, celia, ambulatory,
# Nearest to by: curran, was, in, were, with, broca, lustrous, luthiers,
# Nearest to so: dumfries, ginsberg, lockheed, pakistani, hel, too, polk, very,
# Nearest to for: of, with, against, reinstate, from, torgau, practitioner, containing,
# Nearest to often: frequently, also, sometimes, there, commonly, now, usually, widely,
# Nearest to history: superstars, taxation, travelogues, ganges, province, thrice, yamaguchi, wheatstone,
# Nearest to zero: five, eight, seven, four, six, three, nine, two,
# Nearest to may: can, could, would, will, must, should, might, pyongyang,
# Nearest to new: mistrust, qualifications, base, constructivism, ramzi, hovering, dtds, nostalgic,
# Average loss at step 32000: 3.502946
# Average loss at step 34000: 3.492348
# Average loss at step 36000: 3.453018
# Average loss at step 38000: 3.305728
# Average loss at step 40000: 3.431764
# Nearest to s: his, lederman, distinguishes, bender, magenta, her, boles, malawi,
# Nearest to eight: seven, nine, six, five, four, three, zero, two,
# Nearest to is: was, are, be, if, has, hammond, clap, breasts,
# Nearest to some: many, these, several, each, most, any, different, their,
# Nearest to up: them, out, him, down, me, kitten, jun, handshake,
# Nearest to b: d, r, UNK, w, rory, f, phospholipids, c,
# Nearest to during: after, when, in, since, at, before, corfu, through,
# Nearest to war: celia, eider, gch, margherita, outcrops, wasting, gundobad, shrouded,
# Nearest to by: with, curran, lustrous, collier, exploitative, be, broca, as,
# Nearest to so: too, dumfries, ginsberg, polk, very, more, lockheed, hel,
# Nearest to for: containing, nobel, if, practitioner, saya, watery, reinstate, during,
# Nearest to often: also, sometimes, usually, frequently, commonly, generally, typically, who,
# Nearest to history: province, wheatstone, ganges, qualifiers, travelogues, shakespeare, thrice, crts,
# Nearest to zero: five, seven, nine, eight, six, four, three, two,
# Nearest to may: can, will, could, would, might, must, should, acuity,
# Nearest to new: englishmen, hovering, brett, advent, ncia, modern, buckinghamshire, ramzi,
# Average loss at step 42000: 3.434900
# Average loss at step 44000: 3.450797
# Average loss at step 46000: 3.453114
# Average loss at step 48000: 3.352793
# Average loss at step 50000: 3.382031
# Nearest to s: whose, distinguishes, and, modernity, lederman, nightfall, his, myst,
# Nearest to eight: six, nine, seven, four, five, three, zero, two,
# Nearest to is: was, has, are, although, be, does, became, nnn,
# Nearest to some: many, these, several, both, most, the, all, those,
# Nearest to up: them, out, down, off, him, me, amaranth, jun,
# Nearest to b: d, r, c, f, cubic, valle, x, w,
# Nearest to during: after, when, in, at, before, since, under, taro,
# Nearest to war: celia, wasting, eider, shrouded, hosea, oysters, aranese, klaproth,
# Nearest to by: was, curran, lustrous, with, under, through, broca, in,
# Nearest to so: too, then, wolsey, dumfries, before, when, uris, thus,
# Nearest to for: while, against, containing, obrenovi, paranoia, allotrope, from, practitioner,
# Nearest to often: usually, sometimes, frequently, generally, commonly, also, now, still,
# Nearest to history: province, crts, list, ganges, thrice, italy, leda, qualifiers,
# Nearest to zero: five, seven, eight, six, four, three, nine, two,
# Nearest to may: can, could, would, will, might, must, should, cannot,
# Nearest to new: parliamentary, hitchhikers, astor, neuron, computer, treating, cherries, englishmen,
# Average loss at step 52000: 3.434438
# Average loss at step 54000: 3.429326
# Average loss at step 56000: 3.439735
# Average loss at step 58000: 3.399120
# Average loss at step 60000: 3.393571
# Nearest to s: lederman, wallet, distinguishes, whose, icrm, deranged, fernando, minuet,
# Nearest to eight: six, nine, seven, four, five, three, zero, two,
# Nearest to is: was, nnn, are, has, be, although, cryptology, contains,
# Nearest to some: many, several, these, any, most, all, chalukyas, different,
# Nearest to up: out, down, them, off, him, amaranth, back, jun,
# Nearest to b: d, r, f, c, m, n, p, x,
# Nearest to during: after, when, before, following, since, in, until, although,
# Nearest to war: canby, celia, wasting, merian, hosea, oysters, seekers, eider,
# Nearest to by: curran, with, broca, hypertension, exploitative, was, through, hashemite,
# Nearest to so: too, intensively, then, thus, partitioned, if, shirts, sometimes,
# Nearest to for: of, containing, if, including, cooperatively, when, reinstate, to,
# Nearest to often: sometimes, usually, frequently, commonly, generally, also, now, typically,
# Nearest to history: province, list, ganges, rosenzweig, defying, juggling, development, leda,
# Nearest to zero: five, seven, four, eight, six, nine, three, two,
# Nearest to may: can, will, would, could, must, should, might, cannot,
# Nearest to new: cherries, parliamentary, cyclops, astor, bested, different, kazimierz, dtds,
# Average loss at step 62000: 3.240074
# Average loss at step 64000: 3.252364
# Average loss at step 66000: 3.402612
# Average loss at step 68000: 3.395412
# Average loss at step 70000: 3.356414
# Nearest to s: whose, lederman, baker, discoid, boles, deranged, scarlatti, icrm,
# Nearest to eight: nine, six, seven, four, five, three, zero, one,
# Nearest to is: was, are, has, be, became, although, does, makes,
# Nearest to some: many, several, these, any, those, most, conspicuous, their,
# Nearest to up: them, out, down, off, amaranth, him, me, back,
# Nearest to b: d, r, f, h, w, m, p, n,
# Nearest to during: after, before, in, until, since, following, at, when,
# Nearest to war: canby, celia, wasting, seekers, acquires, outcrops, eider, oysters,
# Nearest to by: through, using, in, curran, be, exploitative, cassandra, towards,
# Nearest to so: thus, too, sometimes, if, intensively, uris, partitioned, then,
# Nearest to for: in, of, against, gop, if, without, while, lumi,
# Nearest to often: sometimes, usually, commonly, frequently, generally, now, also, widely,
# Nearest to history: list, period, province, crts, philosophy, ganges, italy, shakespeare,
# Nearest to zero: five, six, eight, four, seven, three, nine, two,
# Nearest to may: can, will, could, would, might, must, should, cannot,
# Nearest to new: cherries, churchyard, brett, ramzi, different, kazimierz, bested, certain,
# Average loss at step 72000: 3.378981
# Average loss at step 74000: 3.348551
# Average loss at step 76000: 3.320785
# Average loss at step 78000: 3.350333
# Average loss at step 80000: 3.375875
# Nearest to s: barents, lederman, distinguishes, magenta, extinguisher, fernando, isbn, millar,
# Nearest to eight: nine, six, seven, five, four, three, zero, two,
# Nearest to is: was, has, are, became, although, does, refers, cryptology,
# Nearest to some: many, several, these, any, most, various, certain, other,
# Nearest to up: out, off, them, down, him, kitten, amaranth, back,
# Nearest to b: d, r, f, m, p, c, milled, lawns,
# Nearest to during: after, in, before, when, until, following, at, since,
# Nearest to war: canby, wasting, celia, outcrops, seekers, eider, vascular, intervening,
# Nearest to by: curran, using, exploitative, through, under, hashemite, aristotelian, towards,
# Nearest to so: too, before, thus, anything, abrasive, uris, shirts, partitioned,
# Nearest to for: torgau, elan, stabilizes, evolutionist, throbbing, corrino, vinod, against,
# Nearest to often: sometimes, usually, commonly, frequently, generally, typically, still, now,
# Nearest to history: list, ganges, stateless, crts, cramps, classification, conventional, encyclopedia,
# Nearest to zero: five, seven, four, eight, three, six, nine, two,
# Nearest to may: can, will, could, might, would, must, should, cannot,
# Nearest to new: ramzi, marrakech, modern, cherries, englishmen, amalthea, stomping, different,
# Average loss at step 82000: 3.406740
# Average loss at step 84000: 3.412750
# Average loss at step 86000: 3.391352
# Average loss at step 88000: 3.351830
# Average loss at step 90000: 3.367534
# Nearest to s: lederman, distinguishes, his, isbn, unmolested, whose, her, your,
# Nearest to eight: seven, nine, five, six, four, three, zero, one,
# Nearest to is: was, has, are, be, although, seems, cae, does,
# Nearest to some: many, several, these, any, most, those, certain, this,
# Nearest to up: out, off, down, them, together, back, him, amaranth,
# Nearest to b: r, d, f, p, milled, lawns, mile, c,
# Nearest to during: after, until, in, before, when, through, at, under,
# Nearest to war: canby, during, wasting, outcrops, eider, celia, nepal, hosea,
# Nearest to by: through, curran, with, exploitative, under, when, using, fellow,
# Nearest to so: too, thus, before, shirts, uris, anything, jumo, supercomputing,
# Nearest to for: during, of, against, predominate, torgau, when, to, while,
# Nearest to often: sometimes, usually, commonly, frequently, generally, typically, still, now,
# Nearest to history: list, ganges, crts, stateless, period, russa, conventional, periods,
# Nearest to zero: five, seven, eight, six, four, nine, three, two,
# Nearest to may: can, could, will, must, would, might, should, cannot,
# Nearest to new: particular, different, ramzi, modern, stratification, churchyard, navigational, dtds,
# Average loss at step 92000: 3.398727
# Average loss at step 94000: 3.256556
# Average loss at step 96000: 3.357727
# Average loss at step 98000: 3.241724
# Average loss at step 100000: 3.358684
# Nearest to s: lederman, whose, his, my, catamarans, the, burghers, avesta,
# Nearest to eight: nine, seven, six, five, four, three, zero, two,
# Nearest to is: was, has, became, refers, are, be, kabaddi, seems,
# Nearest to some: many, several, these, any, their, certain, most, those,
# Nearest to up: out, off, them, together, down, him, back, amaranth,
# Nearest to b: d, r, rory, historiae, asians, vegetable, w, privatised,
# Nearest to during: after, in, through, before, until, following, since, when,
# Nearest to war: canby, outcrops, battle, wasting, eider, hosea, celia, nepal,
# Nearest to by: through, when, be, including, curran, under, exploitative, using,
# Nearest to so: thus, too, then, therefore, uris, shirts, when, chevron,
# Nearest to for: brooding, when, against, including, vinod, gop, during, reinstate,
# Nearest to often: sometimes, usually, generally, frequently, commonly, typically, widely, now,
# Nearest to history: list, conventional, narrative, ballarat, ganges, crts, stateless, mordred,
# Nearest to zero: five, four, six, seven, eight, nine, three, two,
# Nearest to may: can, could, might, must, would, will, should, cannot,
# Nearest to new: different, ramzi, particular, englishmen, modern, amalthea, stratification, aldrin,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %%
data_index = 0

def generate_batch_cbow(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  context_window = 2 * skip_window
  assert batch_size % context_window == 0
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = context_window + 1
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window
    targets_to_avoid = [skip_window]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span-1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[target]
      labels[i * num_skips + j, 0] = buffer[skip_window]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  # merge labels
  # subsample every `context_window` elements
  labels_merged = labels[::context_window]
  
  return batch, labels_merged

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch_cbow(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8//(2*skip_window))])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['as', 'anarchism', 'a', 'originated', 'term', 'as', 'of', 'a']
#     labels: ['originated', 'as', 'a', 'term']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['anarchism', 'term', 'a', 'originated', 'as', 'of', 'term', 'originated']
#     labels: ['as', 'a']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
context_window = 2 * skip_window
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size // context_window, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # sum every `context_window` word embedding into one
  segment_ids = tf.constant([i // context_window for i in range(batch_size)])
  
  embed = tf.segment_sum(embed, segment_ids=segment_ids)
  
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))
  

  # Optimizer.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

loss_cbow = []


with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch_cbow(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    # _, l = tdb.debug([optimizer, loss], feed_dict=feed_dict, session=session)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      loss_cbow.append(average_loss)
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 50000 == 0:
      sim = similarity.eval()
      for i in list(range(1, valid_size)):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in list(range(1, top_k)):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings_cbow = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.008543
# Nearest to when: mails, governed, medians, oligarchy, play, herm, yauch,
# Nearest to years: occasions, kurt, philosophicus, bar, campbell, philadelphia, railways,
# Nearest to th: litovsk, probable, torrents, bandleader, stol, israelite, amtrak,
# Nearest to and: helmet, kidnapping, korzybski, natufian, ule, hiking, guthrie,
# Nearest to was: marshy, sidewalk, lamar, soured, empties, inspirations, engagement,
# Nearest to has: youngest, changes, scilly, kampong, thrilling, chromatic, helvetii,
# Nearest to there: hair, duct, nerva, baresi, ih, ticino, relevant,
# Nearest to only: collectivized, ninhursag, dekalb, fretting, unsolved, peerless, sanctions,
# Nearest to at: pickford, fremont, dasyprocta, islets, undemocratic, fewer, maha,
# Nearest to than: postgraduate, monotheism, manors, supine, usher, quadrangle, imaging,
# Nearest to such: halen, receptive, licensing, weathering, wahhabism, fayette, interventionism,
# Nearest to or: adenine, pleasuredome, homework, timecode, speculative, castor, mu,
# Nearest to to: beauties, solitary, faculty, semper, pronunciation, saskatoon, sorted,
# Nearest to who: solidify, edmonton, bartolom, tighter, disillusionment, disgraced, shedding,
# Nearest to history: dreaded, klaproth, qigong, curses, temporarily, vulnerability, telnet,
# Average loss at step 2000: 4.217168
# Average loss at step 4000: 3.641953
# Average loss at step 6000: 3.539036
# Average loss at step 8000: 3.393072
# Average loss at step 10000: 3.298947
# Average loss at step 12000: 3.271329
# Average loss at step 14000: 3.244114
# Average loss at step 16000: 3.023289
# Average loss at step 18000: 3.062340
# Average loss at step 20000: 3.159552
# Average loss at step 22000: 3.115403
# Average loss at step 24000: 3.070453
# Average loss at step 26000: 3.050772
# Average loss at step 28000: 3.067345
# Average loss at step 30000: 3.078123
# Average loss at step 32000: 3.074897
# Average loss at step 34000: 3.052812
# Average loss at step 36000: 2.996980
# Average loss at step 38000: 2.795309
# Average loss at step 40000: 2.978218
# Average loss at step 42000: 2.983305
# Average loss at step 44000: 2.984231
# Average loss at step 46000: 2.978291
# Average loss at step 48000: 2.880403
# Average loss at step 50000: 2.897751
# Nearest to when: after, before, where, while, during, against, although,
# Nearest to years: months, decades, times, weeks, year, centuries, tolbert,
# Nearest to th: nd, amtrak, three, dreadnoughts, bce, five, nineteenth,
# Nearest to and: but, of, in, pohl, than, whilst, including,
# Nearest to was: became, were, has, becomes, had, been, sac,
# Nearest to has: have, is, was, makes, having, previously, eben,
# Nearest to there: it, now, she, he, pons, still, believed,
# Nearest to only: unborn, since, distilled, usually, polynesia, geoffroy, commercially,
# Nearest to at: in, toward, neat, under, when, zoological, after,
# Nearest to than: or, kreutzmann, much, and, inclination, rosenzweig, reset,
# Nearest to such: defined, known, regarded, lagers, including, arminian, act,
# Nearest to or: vs, norsk, than, convinces, originality, belligerent, pluralized,
# Nearest to to: could, may, effigy, will, can, towards, wcl,
# Nearest to who: she, which, generally, have, they, never, illuminated,
# Nearest to history: philosophy, baltic, franchising, horton, fabricated, annalen, encyclopedias,
# Average loss at step 52000: 2.953854
# Average loss at step 54000: 2.942986
# Average loss at step 56000: 2.964842
# Average loss at step 58000: 2.876181
# Average loss at step 60000: 2.887296
# Average loss at step 62000: 2.688269
# Average loss at step 64000: 2.704901
# Average loss at step 66000: 2.879876
# Average loss at step 68000: 2.891353
# Average loss at step 70000: 2.837131
# Average loss at step 72000: 2.860121
# Average loss at step 74000: 2.819206
# Average loss at step 76000: 2.809588
# Average loss at step 78000: 2.820522
# Average loss at step 80000: 2.852800
# Average loss at step 82000: 2.878432
# Average loss at step 84000: 2.892884
# Average loss at step 86000: 2.852385
# Average loss at step 88000: 2.800178
# Average loss at step 90000: 2.817717
# Average loss at step 92000: 2.857915
# Average loss at step 94000: 2.689812
# Average loss at step 96000: 2.827945
# Average loss at step 98000: 2.689908
# Average loss at step 100000: 2.813041
# Nearest to when: before, while, unless, although, though, where, after,
# Nearest to years: months, decades, minutes, weeks, centuries, year, hours,
# Nearest to th: nineteenth, nd, bc, fifth, four, rd, lucid,
# Nearest to and: but, although, including, when, of, exploitable, while,
# Nearest to was: became, has, being, had, were, originally, becomes,
# Nearest to has: have, is, was, having, makes, since, maintains,
# Nearest to there: now, still, we, pons, he, she, it,
# Nearest to only: no, battering, latter, already, olympics, properly, instincts,
# Nearest to at: instants, lice, in, near, on, timer, woodruff,
# Nearest to than: mansion, falsificationism, derek, and, excitable, dwarfed, much,
# Nearest to such: known, defined, regarded, act, many, served, follows,
# Nearest to or: than, vs, slowdown, xf, deimos, asclepius, highlanders,
# Nearest to to: could, towards, would, can, should, cannot, shall,
# Nearest to who: he, she, often, formerly, nor, which, typically,
# Nearest to history: list, production, bureau, sideband, underside, ryder, mondial,

# %%
print(len(loss_cbow))
# Out:
# 51

# %%
 
import matplotlib.pyplot as plt

steps = np.arange(len(loss_cbow))
fig, ax = plt.subplots()

ax.plot(steps, loss_skip_gram, 'b', label="skip gram")
ax.plot(steps, loss_cbow, 'g', label="cbow")

# Now add the legend with some customizations.
legend = ax.legend(loc='upper center', shadow=True)

plt.show()

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings_cbow[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
